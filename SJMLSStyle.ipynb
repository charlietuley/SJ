# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
df = pd.read_csv('MLSStyle1 - Sheet1.csv')

# %%
df
# Out:
#                Squad   SoT  npxG/Sh    PPA  CrsPA      %Live      %Dead  \
# 0        Atlanta Utd  4.35     0.09   7.41   2.18  72.371416   8.284024
# 1          Austin FC  4.29     0.10   9.41   2.47  73.915117   9.680496
# 2        CF Montréal  3.76     0.11   8.00   1.79  73.569482   8.174387
# 3       Chicago Fire  4.53     0.09   8.53   2.71  72.628234  12.165229
# 4    Colorado Rapids  4.32     0.10   7.50   2.06  73.597056   8.371665
# 5      Columbus Crew  3.94     0.10   6.97   1.91  70.550508   8.337787
# 6        D.C. United  4.44     0.11   8.56   2.26  69.325736  10.066477
# 7      FC Cincinnati  3.94     0.09   6.47   1.32  65.940055   9.918256
# 8          FC Dallas  4.24     0.11   7.03   1.79  71.812408   8.744504
# 9     Houston Dynamo  4.12     0.09   6.59   1.91  72.597137   8.895706
# 10       Inter Miami  3.47     0.10   6.62   1.65  72.066327   9.948980
# 11         LA Galaxy  4.26     0.11   8.94   2.47  76.663452   7.810993
# ...

# %%
features = ['SoT','npxG/Sh','PPA','CrsPA','%Live','%Dead','%Drib','Att 3rd','Att Pen']
x = df.loc[:, features].values

# %%
x = StandardScaler().fit_transform(x)

# %%
pd.DataFrame(data = x, columns = features).head()
# Out:
#         SoT   npxG/Sh       PPA     CrsPA     %Live     %Dead     %Drib  \
# 0  0.058394 -1.679140 -0.536157  0.046168  0.303148 -0.701117  1.382200
# 1 -0.061351 -0.345705  0.879613  0.715596  0.795241  0.080216 -0.147614
# 2 -1.119098  0.987730 -0.118505 -0.854099  0.685061 -0.762460  0.748085
# 3  0.417629 -1.679140  0.256674  1.269606  0.385016  1.470438 -1.170544
# 4 -0.001478 -0.345705 -0.472448 -0.230838  0.693851 -0.652082  1.322701
#
#     Att 3rd   Att Pen
# 0 -0.247735 -0.359654
# 1  0.965988  0.274375
# 2 -0.049903 -0.126064
# 3 -0.135452  0.140895
# 4 -0.429526  0.140895

# %%
pca = PCA(n_components=2)

# %%
principalComponents = pca.fit_transform(x)

# %%
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
principalDf
# Out:
#     principal component 1  principal component 2
# 0                0.532696               0.954809
# 1               -1.287698              -0.227010
# 2                0.074984               1.864875
# 3                0.038996              -2.306962
# 4                0.055524               1.213246
# 5                1.425386               0.762329
# 6                0.004526              -0.638281
# 7                3.422908               0.978754
# 8                0.988072               0.924622
# 9                1.496502              -0.036078
# 10               2.943084               0.432286
# 11              -1.816065               0.570621
# 12              -3.471508               1.344242
# 13              -1.341300               1.001999
# 14               1.315184              -2.674443
# 15              -3.735567              -0.988947
# 16               0.316482               0.081216
# 17              -3.378794              -1.724438
# ...

# %%
principalDf['Euc Dist'] = np.sqrt(((principalDf['principal component 1']-1.443118)**2)+((principalDf['principal component 2']+0.212162)**2))

# %%
principalDf
# Out:
#     principal component 1  principal component 2      Euc Dist
# 0                0.532696               0.954809  1.480098e+00
# 1               -1.287698              -0.227010  2.730856e+00
# 2                0.074984               1.864875  2.487142e+00
# 3                0.038996              -2.306962  2.521854e+00
# 4                0.055524               1.213246  1.989273e+00
# 5                1.425386               0.762329  9.746525e-01
# 6                0.004526              -0.638281  1.500375e+00
# 7                3.422908               0.978754  2.310379e+00
# 8                0.988072               0.924622  1.224477e+00
# 9                1.496502              -0.036078  1.839983e-01
# 10               2.943084               0.432286  1.632547e+00
# 11              -1.816065               0.570621  3.351869e+00
# 12              -3.471508               1.344242  5.155186e+00
# 13              -1.341300               1.001999  3.037626e+00
# ...

# %%
teams = df['Squad']
principalDf = principalDf.join(teams)

# %%
principalDf
# Out:
#     principal component 1  principal component 2      Euc Dist  \
# 0                0.532696               0.954809  1.480098e+00
# 1               -1.287698              -0.227010  2.730856e+00
# 2                0.074984               1.864875  2.487142e+00
# 3                0.038996              -2.306962  2.521854e+00
# 4                0.055524               1.213246  1.989273e+00
# 5                1.425386               0.762329  9.746525e-01
# 6                0.004526              -0.638281  1.500375e+00
# 7                3.422908               0.978754  2.310379e+00
# 8                0.988072               0.924622  1.224477e+00
# 9                1.496502              -0.036078  1.839983e-01
# 10               2.943084               0.432286  1.632547e+00
# 11              -1.816065               0.570621  3.351869e+00
# 12              -3.471508               1.344242  5.155186e+00
# 13              -1.341300               1.001999  3.037626e+00
# ...

# %%
principalDf.sort_values(by=['Euc Dist'], inplace=True, ascending=False)

# %%
principalDf
# Out:
#     principal component 1  principal component 2      Euc Dist  \
# 15              -3.735567              -0.988947  5.236619e+00
# 12              -3.471508               1.344242  5.155186e+00
# 17              -3.378794              -1.724438  5.053495e+00
# 24              -2.658919               0.816736  4.229106e+00
# 19              -2.579040              -0.813475  4.066857e+00
# 25              -0.652732               3.066075  3.890942e+00
# 11              -1.816065               0.570621  3.351869e+00
# 13              -1.341300               1.001999  3.037626e+00
# 26               4.277610              -0.517308  2.850870e+00
# 1               -1.287698              -0.227010  2.730856e+00
# 21              -0.537307              -1.907811  2.607164e+00
# 3                0.038996              -2.306962  2.521854e+00
# 2                0.074984               1.864875  2.487142e+00
# 14               1.315184              -2.674443  2.465602e+00
# ...

# %%
#Most similar Attacking
#Houston,Orlando,Portland,Columbus,NYRB

# %%
df = pd.read_csv('MLSStyle - Sheet2.csv')

# %%
df
# Out:
#                Squad    Cmp  Cmp%  PrgDist      %Long  Final 3rd    TB     Sw  \
# 0        Atlanta Utd  452.3  84.6   2698.5  20.321856       28.6  1.03  19.70
# 1          Austin FC  432.5  84.0   2811.4  19.569016       33.4  0.76  17.30
# 2        CF Montréal  432.3  83.9   2799.7  17.569404       33.0  1.09  14.30
# 3       Chicago Fire  367.7  78.8   2597.8  19.644387       26.0  0.76  13.50
# 4    Colorado Rapids  383.9  82.1   2703.3  21.509515       32.1  1.21  16.50
# 5      Columbus Crew  397.6  81.8   2761.2  22.290767       30.5  0.74  15.90
# 6        D.C. United  312.0  75.4   2450.9  24.202128       25.6  0.88  13.60
# 7      FC Cincinnati  384.1  82.8   2403.5  19.780220       24.1  1.21  16.40
# 8          FC Dallas  406.4  82.1   2612.5  20.189784       27.2  1.03  15.60
# 9     Houston Dynamo  328.9  77.8   2333.5  22.072392       27.8  0.97  14.70
# 10       Inter Miami  368.9  82.1   2567.1  21.388827       28.6  1.09  17.50
# ...

# %%
features = ['Cmp','Cmp%','PrgDist','%Long','Final 3rd','TB','Sw','Poss','Def Pen','Def 3rd','Mid 3rd','PrgDist.1','%ProgPassing']
x = df.loc[:, features].values

# %%
x = StandardScaler().fit_transform(x)

# %%
pd.DataFrame(data = x, columns = features).head()
# Out:
#         Cmp      Cmp%   PrgDist     %Long  Final 3rd        TB        Sw  \
# 0  1.579459  1.308372  0.347886 -0.224345  -0.328745  0.688922  1.490493
# 1  1.108554  1.103978  1.086473 -0.553109   1.209356 -0.602143  0.678044
# 2  1.103798  1.069913  1.009932 -1.426336   1.081181  0.975825 -0.337517
# 3 -0.432587 -0.667434 -0.310888 -0.520194  -1.161884 -0.602143 -0.608334
# 4 -0.047302  0.456732  0.379288  0.294304   0.792787  1.549632  0.407228
#
#        Poss   Def Pen   Def 3rd   Mid 3rd  PrgDist.1  %ProgPassing
# 0  2.324297  1.060318  1.505883  1.655034   2.019953     -2.244682
# 1  1.248299  1.944909  1.361584 -0.514327   1.152997     -0.792473
# 2  0.900182 -0.132540  0.457305  1.319415   1.056846     -0.725548
# 3 -0.080876  0.323159 -0.321913  0.322288  -0.735869      0.752249
# 4 -0.555581 -0.293374 -0.225713 -0.509463  -0.176440      0.420088

# %%
pca = PCA(n_components=2)

# %%
principalComponents = pca.fit_transform(x)

# %%
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
principalDf
# Out:
#     principal component 1  principal component 2
# 0               -4.703369               1.662269
# 1               -3.156309               1.082936
# 2               -3.065992              -1.510085
# 3                1.192747              -0.016361
# 4                0.008100              -0.592437
# 5               -0.112267               0.446082
# 6                4.395891               0.010295
# 7               -0.457626               2.252412
# 8               -1.799365               2.123664
# 9                3.249581               0.594435
# 10               1.173232               0.108508
# 11              -4.506557              -0.615010
# 12               0.677076              -2.931148
# 13               0.519721              -2.423840
# 14               2.441649              -0.274476
# 15              -0.558101              -1.541696
# 16               5.605906              -0.139693
# 17              -1.509479              -1.897662
# ...

# %%
principalDf['Euc Dist'] = np.sqrt(((principalDf['principal component 1']+0.325996)**2)+((principalDf['principal component 2']-3.353821)**2))

# %%
principalDf
# Out:
#     principal component 1  principal component 2      Euc Dist
# 0               -4.703369               1.662269  4.692840e+00
# 1               -3.156309               1.082936  3.628717e+00
# 2               -3.065992              -1.510085  5.582577e+00
# 3                1.192747              -0.016361  3.696580e+00
# 4                0.008100              -0.592437  3.960375e+00
# 5               -0.112267               0.446082  2.915583e+00
# 6                4.395891               0.010295  5.785791e+00
# 7               -0.457626               2.252412  1.109247e+00
# 8               -1.799365               2.123664  1.919401e+00
# 9                3.249581               0.594435  4.516521e+00
# 10               1.173232               0.108508  3.574876e+00
# 11              -4.506557              -0.615010  5.764435e+00
# 12               0.677076              -2.931148  6.364510e+00
# 13               0.519721              -2.423840  5.839229e+00
# ...

# %%
teams = df['Squad']
principalDf = principalDf.join(teams)

# %%
principalDf.head()
# Out:
#    principal component 1  principal component 2  Euc Dist            Squad
# 0              -4.703369               1.662269  4.692840      Atlanta Utd
# 1              -3.156309               1.082936  3.628717        Austin FC
# 2              -3.065992              -1.510085  5.582577      CF Montréal
# 3               1.192747              -0.016361  3.696580     Chicago Fire
# 4               0.008100              -0.592437  3.960375  Colorado Rapids

# %%
principalDf.sort_values(by=['Euc Dist'], inplace=True, ascending=False)

# %%
principalDf
# Out:
#     principal component 1  principal component 2      Euc Dist  \
# 16               5.605906              -0.139693  6.884192e+00
# 12               0.677076              -2.931148  6.364510e+00
# 24              -5.482228              -0.147887  6.232872e+00
# 13               0.519721              -2.423840  5.839229e+00
# 6                4.395891               0.010295  5.785791e+00
# 11              -4.506557              -0.615010  5.764435e+00
# 2               -3.065992              -1.510085  5.582577e+00
# 17              -1.509479              -1.897662  5.383187e+00
# 25              -0.637655              -1.973181  5.336111e+00
# 15              -0.558101              -1.541696  4.901016e+00
# 0               -4.703369               1.662269  4.692840e+00
# 14               2.441649              -0.274476  4.563376e+00
# 9                3.249581               0.594435  4.516521e+00
# 18              -0.739317              -0.966629  4.340176e+00
# ...

# %%
#Most similar in possession
#Cincinnati,Dallas,Columbus,RSL,Seattle

# %%
df = pd.read_csv('MLSStyle - Sheet3.csv')

# %%
df.head()
# Out:
#              Squad     %  Padj Def 3rd  Padj Mid 3rd  Padj Final 3rd  \
# 0      Atlanta Utd  28.4     15.883843     12.492691        3.040343
# 1        Austin FC  28.0     16.994763      8.867618        4.298357
# 2      CF Montréal  28.9     12.283113      9.139323        3.229686
# 3     Chicago Fire  31.4     14.541161     13.545884        4.419703
# 4  Colorado Rapids  25.3     12.259970      9.420647        3.676350
#
#    Padj Def 3rd.1  Padj Middle 3rd  Padj Final 3rd.1   %Def 3rd   %Mid 3rd  \
# 0      101.929448       120.054570         52.231534  50.621118  39.813665
# 1       95.358497       101.137800         63.933538  56.347305  29.401198
# 2       78.165264       110.462120         63.562962  49.652778  36.944444
# 3       76.923077       105.937922         56.680162  44.663212  41.606218
# 4       73.362875       114.065321         55.309371  48.506493  37.272727
#
#     %fin 3rd  %Def 3rd.1   %mid 3rd  %final 3rd
# 0   9.689441   37.171286  43.781095   19.047619
# ...

# %%
features = ['%','Padj Def 3rd','Padj Mid 3rd','Padj Final 3rd','Padj Def 3rd.1','Padj Middle 3rd','Padj Final 3rd.1','%Def 3rd','%Mid 3rd','%fin 3rd','%Def 3rd.1','%mid 3rd','%final 3rd']
x = df.loc[:, features].values

# %%
x = StandardScaler().fit_transform(x)

# %%
pd.DataFrame(data = x, columns = features).head()
# Out:
#           %  Padj Def 3rd  Padj Mid 3rd  Padj Final 3rd  Padj Def 3rd.1  \
# 0 -0.254621      0.505765      0.809170       -1.159673        1.731954
# 1 -0.493742      1.159368     -1.430780        0.320785        0.922478
# 2  0.044282     -1.612706     -1.262892       -0.936850       -1.195556
# 3  1.538794     -0.284195      1.459943        0.463589       -1.348581
# 4 -2.107815     -1.626322     -1.089061       -0.411206       -1.787162
#
#    Padj Middle 3rd  Padj Final 3rd.1  %Def 3rd  %Mid 3rd  %fin 3rd  \
# 0         0.613997         -0.814490  0.210762  0.940865 -1.633611
# 1        -1.129379          0.345614  1.642199 -2.444685  0.438555
# 2        -0.270047          0.308876 -0.031305  0.007955 -0.104662
# 3        -0.686998         -0.373466 -1.278601  1.523703  0.131337
# 4         0.062026         -0.509362 -0.317854  0.114695  0.572076
#
#    %Def 3rd.1  %mid 3rd  %final 3rd
# 0    1.077350  0.238670   -1.509212
# 1    0.905824 -2.215857    0.580726
# ...

# %%
pca = PCA(n_components=2)

# %%
principalComponents = pca.fit_transform(x)

# %%
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
principalDf
# Out:
#     principal component 1  principal component 2
# 0               -1.854184              -1.507172
# 1               -2.625123              -0.714512
# 2                0.546031               2.362336
# 3                2.129064               0.166473
# 4                0.620396               3.522057
# 5               -1.105335               0.704255
# 6                1.380510              -0.221250
# 7               -2.788088              -1.660229
# 8               -2.007127              -1.347874
# 9               -0.251726               1.905918
# 10              -1.788364               0.121798
# 11              -0.930610               0.710576
# 12               3.044570              -2.125294
# 13               2.418032              -0.135495
# 14              -0.821557               1.490690
# 15               0.488359              -0.086613
# 16               6.753107              -2.636520
# 17               4.613218               0.530354
# ...

# %%
principalDf['Euc Dist'] = np.sqrt(((principalDf['principal component 1']+1.354919)**2)+((principalDf['principal component 2']+2.882028)**2))

# %%
principalDf
# Out:
#     principal component 1  principal component 2      Euc Dist
# 0               -1.854184              -1.507172  1.462701e+00
# 1               -2.625123              -0.714512  2.512279e+00
# 2                0.546031               2.362336  5.578258e+00
# 3                2.129064               0.166473  4.629416e+00
# 4                0.620396               3.522057  6.701804e+00
# 5               -1.105335               0.704255  3.594957e+00
# 6                1.380510              -0.221250  3.816060e+00
# 7               -2.788088              -1.660229  1.883286e+00
# 8               -2.007127              -1.347874  1.667034e+00
# 9               -0.251726               1.905918  4.913397e+00
# 10              -1.788364               0.121798  3.034937e+00
# 11              -0.930610               0.710576  3.617574e+00
# 12               3.044570              -2.125294  4.464096e+00
# 13               2.418032              -0.135495  4.666755e+00
# ...

# %%
teams = df['Squad']
principalDf = principalDf.join(teams)

# %%
principalDf.head()
# Out:
#    principal component 1  principal component 2  Euc Dist            Squad
# 0              -1.854184              -1.507172  1.462701      Atlanta Utd
# 1              -2.625123              -0.714512  2.512279        Austin FC
# 2               0.546031               2.362336  5.578258      CF Montréal
# 3               2.129064               0.166473  4.629416     Chicago Fire
# 4               0.620396               3.522057  6.701804  Colorado Rapids

# %%
principalDf.sort_values(by=['Euc Dist'], inplace=True, ascending=False)

# %%
principalDf
# Out:
#     principal component 1  principal component 2      Euc Dist  \
# 16               6.753107              -2.636520  8.111742e+00
# 17               4.613218               0.530354  6.874810e+00
# 4                0.620396               3.522057  6.701804e+00
# 24               3.991359               1.064232  6.644972e+00
# 2                0.546031               2.362336  5.578258e+00
# 25              -0.027025               2.231636  5.283262e+00
# 9               -0.251726               1.905918  4.913397e+00
# 20              -5.084529              -0.042566  4.687487e+00
# 13               2.418032              -0.135495  4.666755e+00
# 3                2.129064               0.166473  4.629416e+00
# 12               3.044570              -2.125294  4.464096e+00
# 14              -0.821557               1.490690  4.405126e+00
# 26              -0.445335               1.373752  4.351896e+00
# 6                1.380510              -0.221250  3.816060e+00
# ...

# %%
#Most similar Defensively
#Atlanta,Dallas,Seattle,Cincinnati,Austin
